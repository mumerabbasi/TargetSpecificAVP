# %%
import carla

# Connect to CARLA server on port 2150
client = carla.Client("localhost", 2150)
client.set_timeout(10.0)

# Load Town04
world = client.load_world("Town04")

print("Connected and loaded Town04!")
# Out:
# Connected and loaded Town04!
